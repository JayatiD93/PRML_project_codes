# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/PRML
# Out:
# /content/drive/MyDrive/PRML

# %%
# %ls
# Out:
# data1.csv                            loss_history_imagenet_34layer_2.csv
# data1_plain.csv                      loss_history_plain1.csv
# data1_testing.csv                    loss_history_plain2.csv
# data1_testing_plain.csv              loss_history_plain3.csv
# data2.csv                            loss_history_plain4.csv
# data2_plain.csv                      loss_history_plain5.csv
# data2_testing.csv                    loss_history_plain6.csv
# data2_testing_plain.csv              loss_history_plain7.csv
# data3.csv                            loss_history_plain8.csv
# data3_plain.csv                      model2.csv
# data3_testing.csv                    model3.csv
# data3_testing_plain.csv              model.csv
# data4.csv                            my_model1_2.h5
# data4_plain.csv                      my_model.h5
# data4_testing.csv                    plainnet_imagenet_18_test_100.csv
# data4_testing_plain.csv              plainnet_imagenet_18_test.csv
# imagenette2-160/                     plainnet_imagenet_18_train_100.csv
# loss_history1.csv                    plainnet_imagenet_18_train.csv
# loss_history2.csv                    plainnet_imagenet_34_test_100.csv
# loss_history3.csv                    plainnet_imagenet_34_test.csv
# loss_history4.csv                    plainnet_imagenet_34_train_100.csv
# loss_history_imagenet1.csv           plainnet_imagenet_34_train.csv
# loss_history_imagenet1_plainnet.csv  resnet_imagenet_18_test.csv
# loss_history_imagenet2.csv           resnet_imagenet_18_train.csv
# loss_history_imagenet2_plainnet.csv  resnet_imagenet_34_test.csv
# loss_history_imagenet_34layer_1.csv  resnet_imagenet_34_train.csv

# %%
import numpy as np
import csv
import matplotlib.pylab as plt
from scipy.optimize import curve_fit
from scipy import integrate as intg

# %%
with open("/content/drive/MyDrive/PRML/plainnet_imagenet_18_train_100.csv",'r') as i:           #open a file in directory of this script for reading 
    rawdata1 = list(csv.reader(i,delimiter=","))   #make a list of data in file

# %%
exampledata1 = np.array(rawdata1[1:],dtype=np.float)    #convert to data array

xdata1 = exampledata1[:,0]
ydata1 = exampledata1[:,1]

# %%
with open("/content/drive/MyDrive/PRML/plainnet_imagenet_18_test_100.csv",'r') as m:           #open a file in directory of this script for reading 
    rawdata1_testing = list(csv.reader(m,delimiter=","))   #make a list of data in file

# %%
exampledata1_testing = np.array(rawdata1_testing[1:],dtype=np.float)    #convert to data array

xdata1_testing = exampledata1_testing[:,0]
ydata1_testing = exampledata1_testing[:,1]

# %%
with open("/content/drive/MyDrive/PRML/plainnet_imagenet_34_train_100.csv",'r') as j:           #open a file in directory of this script for reading 
    rawdata2 = list(csv.reader(j,delimiter=","))   #make a list of data in file

# %%
exampledata2 = np.array(rawdata2[1:],dtype=np.float)    #convert to data array

xdata2 = exampledata2[:,0]
ydata2 = exampledata2[:,1]

# %%
with open("/content/drive/MyDrive/PRML/plainnet_imagenet_34_test_100.csv",'r') as n:           #open a file in directory of this script for reading 
    rawdata2_testing = list(csv.reader(n,delimiter=","))   #make a list of data in file

# %%
exampledata2_testing = np.array(rawdata2_testing[1:],dtype=np.float)    #convert to data array

xdata2_testing = exampledata2_testing[:,0]
ydata2_testing = exampledata2_testing[:,1]

# %%
plt.figure(1,dpi=120)
plt.yscale('linear')
plt.xscale('linear')
#plt.xlim(0,4)
#plt.ylim(0,2.5)
#plt.title("Example Data")
plt.xlabel('Epoch')
plt.ylabel('Error %')
plt.plot(xdata1,ydata1,'c-',label="Training 18-layer")
plt.plot(xdata1_testing,ydata1_testing,'c--',label="Testing 18-layer")
plt.plot(xdata2,ydata2,'r-',label="Training 34-layer")
plt.plot(xdata2_testing,ydata2_testing,'r--',label="Testing 34-layer")
#plt.plot(xdata3,ydata3,'k-',label="Training 44-layer")
#plt.plot(xdata3_testing,ydata3_testing,'k--',label="Testing 44-layer")
#plt.plot(xdata4,ydata4,color='g',label="Training 56-layer")
#plt.plot(xdata4_testing,ydata4_testing,color='g',label="Testing 56-layer")
plt.grid(color='y')
plt.legend()
plt.show()
