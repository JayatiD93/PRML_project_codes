# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/PRML
# Out:
# /content/drive/MyDrive/PRML

# %%
ls
# Out:
# data1.csv                data4.csv                loss_history_plain4.csv
# data1_plain.csv          data4_plain.csv          loss_history_plain5.csv
# data1_testing.csv        data4_testing.csv        loss_history_plain6.csv
# data1_testing_plain.csv  data4_testing_plain.csv  loss_history_plain7.csv
# data2.csv                Imagenette/              loss_history_plain8.csv
# data2_plain.csv          loss_history1.csv        model2.csv
# data2_testing.csv        loss_history2.csv        model3.csv
# data2_testing_plain.csv  loss_history3.csv        model.csv
# data3.csv                loss_history4.csv        my_model1_2.h5
# data3_plain.csv          loss_history_plain1.csv  my_model.h5
# data3_testing.csv        loss_history_plain2.csv
# data3_testing_plain.csv  loss_history_plain3.csv

# %%
import numpy as np
import csv
import matplotlib.pylab as plt
from scipy.optimize import curve_fit
from scipy import integrate as intg

# %%
with open("/content/drive/MyDrive/PRML/data1_plain.csv",'r') as i:           #open a file in directory of this script for reading 
    rawdata1 = list(csv.reader(i,delimiter=","))   #make a list of data in file

# %%
exampledata1 = np.array(rawdata1[1:],dtype=np.float)    #convert to data array

xdata1 = exampledata1[:,0]
ydata1 = exampledata1[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data1_testing_plain.csv",'r') as m:           #open a file in directory of this script for reading 
    rawdata1_testing = list(csv.reader(m,delimiter=","))   #make a list of data in file

# %%
exampledata1_testing = np.array(rawdata1_testing[1:],dtype=np.float)    #convert to data array

xdata1_testing = exampledata1_testing[:,0]
ydata1_testing = exampledata1_testing[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data2_plain.csv",'r') as j:           #open a file in directory of this script for reading 
    rawdata2 = list(csv.reader(j,delimiter=","))   #make a list of data in file

# %%
exampledata2 = np.array(rawdata2[1:],dtype=np.float)    #convert to data array

xdata2 = exampledata2[:,0]
ydata2 = exampledata2[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data2_testing_plain.csv",'r') as n:           #open a file in directory of this script for reading 
    rawdata2_testing = list(csv.reader(n,delimiter=","))   #make a list of data in file

# %%
exampledata2_testing = np.array(rawdata2_testing[1:],dtype=np.float)    #convert to data array

xdata2_testing = exampledata2_testing[:,0]
ydata2_testing = exampledata2_testing[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data3_plain.csv",'r') as k:           #open a file in directory of this script for reading 
    rawdata3 = list(csv.reader(k,delimiter=","))   #make a list of data in file

# %%
exampledata3 = np.array(rawdata3[1:],dtype=np.float)    #convert to data array

xdata3 = exampledata3[:,0]
ydata3 = exampledata3[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data3_testing_plain.csv",'r') as o:           #open a file in directory of this script for reading 
    rawdata3_testing = list(csv.reader(o,delimiter=","))   #make a list of data in file

# %%
exampledata3_testing = np.array(rawdata3_testing[1:],dtype=np.float)    #convert to data array

xdata3_testing = exampledata3_testing[:,0]
ydata3_testing = exampledata3_testing[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data4_plain.csv",'r') as l:           #open a file in directory of this script for reading 
    rawdata4 = list(csv.reader(l,delimiter=","))   #make a list of data in file

# %%
exampledata4 = np.array(rawdata4[1:],dtype=np.float)    #convert to data array

xdata4 = exampledata4[:,0]
ydata4 = exampledata4[:,1]

# %%
with open("/content/drive/MyDrive/PRML/data4_testing_plain.csv",'r') as p:           #open a file in directory of this script for reading 
    rawdata4_testing = list(csv.reader(p,delimiter=","))   #make a list of data in file

# %%
exampledata4_testing = np.array(rawdata4_testing[1:],dtype=np.float)    #convert to data array

xdata4_testing = exampledata4_testing[:,0]
ydata4_testing = exampledata4_testing[:,1]

# %%
plt.figure(1,dpi=120)
plt.yscale('linear')
plt.xscale('linear')
#plt.xlim(0,4)
#plt.ylim(0,2.5)
#plt.title("Example Data")
plt.xlabel('Epoch')
plt.ylabel('Error %')
plt.plot(xdata1,ydata1,'b-',label="Training 20-layer")
plt.plot(xdata1_testing,ydata1_testing,'b--',label="Testing 20-layer")
plt.plot(xdata2,ydata2,'r-',label="Training 32-layer")
plt.plot(xdata2_testing,ydata2_testing,'r--',label="Testing 32-layer")
plt.plot(xdata3,ydata3,'k-',label="Training 44-layer")
plt.plot(xdata3_testing,ydata3_testing,'k--',label="Testing 44-layer")
#plt.plot(xdata4,ydata4,color='g',label="Training 56-layer")
#plt.plot(xdata4_testing,ydata4_testing,color='g',label="Testing 56-layer")
plt.grid(color='y')
plt.legend()
plt.show()
